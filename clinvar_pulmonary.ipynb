# %%
# library imports
import pandas as pd

# %%
# read clinVar results
df = pd.read_table("clinvar_result.txt")
df
# Out:
#                                                   Name  \
# 0    GRCh38/hg38 2q31.1-33.2(chr2:174898848-2039415...
# 1    GRCh38/hg38 2q31.3-36.2(chr2:180513793-2243028...
# 2    GRCh38/hg38 2q32.2-37.3(chr2:188818195-2420652...
# 3    GRCh38/hg38 2q32.2-37.3(chr2:189436149-2418412...
# 4    GRCh38/hg38 2q32.2-37.3(chr2:190310736-2418927...
# ..                                                 ...
# 499                 NM_001204.6(BMPR2):c.77-?_621+?del
# 500                 NM_001204.6(BMPR2):c.77-?_418+?dup
# 501                 NM_001204.6(BMPR2):c.77-?_247+?dup
# 502        NC_000002.12:g.(?_202376327_202567749_?)del
# 503   NG_009363.1:g.(161407_170984)_(171122_181389)del
#
#                                                Gene(s) Protein change  \
# 0    KIAA2012-AS1|LINC01090|LINC01116|LINC01117|LIN...            NaN
# 1    AAMP|ABCA12|ABCB6|ABI2|ACADL|ACSL3|ACSL3-AS1|A...            NaN
# 2    AAMP|ABCA12|ABCB6|ABI2|ACADL|ACKR3|ACSL3|ACSL3...            NaN
# ...

# %%
# unique conditions
df['Condition(s)'].unique()
# Out:
# array(['See cases', 'Pulmonary hypertension, primary, 1',
#        'Pulmonary arterial hypertension',
#        'Idiopathic and/or familial pulmonary arterial hypertension',
#        'Pulmonary arterial hypertension|Pulmonary hypertension, primary, 1',
#        'Primary pulmonary hypertension|not provided',
#        'Pulmonary venoocclusive disease 1|Pulmonary hypertension, primary, 1',
#        'Pulmonary hypertension, primary, 1|Primary pulmonary hypertension',
#        'Primary pulmonary hypertension',
#        'Pulmonary venoocclusive disease 1',
#        'Pulmonary arterial hypertension associated with congenital heart disease',
#        'not provided',
#        'Pulmonary hypertension, primary, 1|Pulmonary venoocclusive disease 1, autosomal dominant',
#        'Pulmonary hypertension, primary, 1|Pulmonary arterial hypertension',
#        'Pulmonary hypertension, primary, dexfenfluramine-associated',
#        'Primary pulmonary hypertension|not specified',
# ...

# %%
search_string = "Pulmonary arterial hypertension"
count_occurrences = [0, 0, 0]
# Count the occurrences of the search string in the "Conditions" column (case insensitive)
count_occurrences[0] = df['Condition(s)'].str.contains(search_string, case=False).sum()
print(count_occurrences)
# Out:
# [89, 0, 0]

# %%
search_string = "Pulmonary hypertension"

# Count the occurrences of the search string in the "Conditions" column (case insensitive)
count_occurrences[1] = df['Condition(s)'].str.contains(search_string, case=False).sum()
print(count_occurrences)
# Out:
# [89, 400, 0]

# %%
search_string = "Pulmonary"

# Count the occurrences of the search string in the "Conditions" column (case insensitive)
count_occurrences[2] = df['Condition(s)'].str.contains(search_string, case=False).sum()
print(count_occurrences)
# Out:
# [89, 400, 460]

# %%
import matplotlib.pyplot as plt

# %%
diseases = ['Pulmonary arterial hypertension', 'Pulmonary hypertension', 'Pulmonary']
plt.bar(diseases, count_occurrences)
plt.xlabel('Search strings')
plt.ylabel('Count')
plt.title('Count for different strings')
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()  # Adjusts the layout to prevent clipping of labels
plt.show()
